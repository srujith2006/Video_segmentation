# %% [markdown]
# <a href="https://colab.research.google.com/github/srujith2006/Video_segmentation/blob/main/input_Cracks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 35.2 MB/s eta 0:00:00
# ...

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-37dc201f-1161-4a51-8fe3-38b5812b61f5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-37dc201f-1161-4a51-8fe3-38b5812b61f5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile
import os

zip_path = "/content/crack.v1-wecar_crack_image.yolov8 (1).zip"
extraction_dir = "/content/crack_data"

os.makedirs(extraction_dir, exist_ok=True)

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extraction_dir)

# %%
import os

for root, dirs, files in os.walk("/content/crack_dataset"):
    print(root)

# %%
# !find /content/crack_data -name data.yaml
# Out:
# /content/crack_data/data.yaml

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/content/crack_data/data.yaml",
    epochs=50,
    imgsz=640,
    batch=16
)
# Out:
# Ultralytics 8.4.60 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !ls /content/runs/detect/train/weights

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7ac4af70-abbe-4bda-b21f-1de394e3e6c4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7ac4af70-abbe-4bda-b21f-1de394e3e6c4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from ultralytics import YOLO

model = YOLO("/content/runs/detect/train-2/weights/best.pt")

model.predict(
    source="wall_video.mp4",
    save=True,
    conf=0.25
)
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/610) /content/wall_video.mp4: 640x384 1 crack, 9.4ms
# video 1/1 (frame 2/610) /content/wall_video.mp4: 640x384 1 crack, 7.1ms
# video 1/1 (frame 3/610) /content/wall_video.mp4: 640x384 1 crack, 12.9ms
# video 1/1 (frame 4/610) /content/wall_video.mp4: 640x384 2 cracks, 6.4ms
# video 1/1 (frame 5/610) /content/wall_video.mp4: 640x384 1 crack, 7.0ms
# ...

# %%
from IPython.display import Video

Video("/content/runs/detect/predict/input_hazard_analysis.mp4", embed=True)
# Out:
# <video controls  >
#  <source src="..._hazard_analysis.mp4" type="None">
#  Your browser does not support the video tag.
#  </video>

# %%
import os

# List contents of the prediction directory to find the annotated video
prediction_dir = '/content/runs/detect/predict-2'
print(f"Contents of {prediction_dir}:")
for item in os.listdir(prediction_dir):
    print(item)
# Out:
# Contents of /content/runs/detect/predict-2:
# wall_video.avi

# %% [markdown]
# Once you have identified the video file name (e.g., `wall_video.mp4` or `input_hazard_analysis.mp4` if it was renamed during prediction), you can download it using the following code. Replace `your_annotated_video_name.mp4` with the actual file name from the output above.

# %%
from google.colab import files

# The annotated video file is named 'wall_video.avi'
download_path = os.path.join(prediction_dir, 'wall_video.avi')
files.download(download_path)
